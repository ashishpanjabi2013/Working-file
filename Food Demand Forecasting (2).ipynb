# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('C:\\Users\\paas9002\\Downloads\\train.csv\\train.csv')

# %%
data.head()
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1379560     1         55     1885          136.83      152.29
# 1  1466964     1         55     1993          136.83      135.83
# 2  1346989     1         55     2539          134.86      135.86
# 3  1338232     1         55     2139          339.50      437.53
# 4  1448490     1         55     2631          243.50      242.50
#
#    emailer_for_promotion  homepage_featured  num_orders
# 0                      0                  0         177
# 1                      0                  0         270
# 2                      0                  0         189
# 3                      0                  0          54
# 4                      0                  0          40

# %%
data.tail()
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 456543  1271326   145         61     1543          484.09      484.09
# 456544  1062036   145         61     2304          482.09      482.09
# 456545  1110849   145         61     2664          237.68      321.07
# 456546  1147725   145         61     2569          243.50      313.34
# 456547  1361984   145         61     2490          292.03      290.03
#
#         emailer_for_promotion  homepage_featured  num_orders
# 456543                      0                  0          68
# 456544                      0                  0          42
# 456545                      0                  0         501
# 456546                      0                  0         729
# 456547                      0                  0         162

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456548 entries, 0 to 456547
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     456548 non-null  int64
#  1   week                   456548 non-null  int64
#  2   center_id              456548 non-null  int64
#  3   meal_id                456548 non-null  int64
#  4   checkout_price         456548 non-null  float64
#  5   base_price             456548 non-null  float64
#  6   emailer_for_promotion  456548 non-null  int64
#  7   homepage_featured      456548 non-null  int64
#  8   num_orders             456548 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 31.3 MB

# %%
data.shape
# Out:
# (456548, 9)

# %%
data.describe()
# Out:
#                  id           week      center_id        meal_id  \
# count  4.565480e+05  456548.000000  456548.000000  456548.000000
# mean   1.250096e+06      74.768771      82.105796    2024.337458
# std    1.443548e+05      41.524956      45.975046     547.420920
# min    1.000000e+06       1.000000      10.000000    1062.000000
# 25%    1.124999e+06      39.000000      43.000000    1558.000000
# 50%    1.250184e+06      76.000000      76.000000    1993.000000
# 75%    1.375140e+06     111.000000     110.000000    2539.000000
# max    1.499999e+06     145.000000     186.000000    2956.000000
#
#        checkout_price     base_price  emailer_for_promotion  \
# count   456548.000000  456548.000000          456548.000000
# mean       332.238933     354.156627               0.081152
# std        152.939723     160.715914               0.273069
# min          2.970000      55.350000               0.000000
# 25%        228.950000     243.500000               0.000000
# ...

# %%
data.isna().sum()
# Out:
# id                       0
# week                     0
# center_id                0
# meal_id                  0
# checkout_price           0
# base_price               0
# emailer_for_promotion    0
# homepage_featured        0
# num_orders               0
# dtype: int64

# %%
data=data.drop(columns='id',axis=1)

# %%
plt.figure(figsize=(25,20),facecolor='lightblue')
plotnumber = 1


for column in data:
    if plotnumber<=10:
        ax=plt.subplot(4,2,plotnumber)
        sns.distplot(data[column], rug=True, hist=False, label='UW', kde_kws={'bw':0.1})
        plt.xlabel(column,fontsize=7)
        
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(25,20),facecolor='lightblue')
plotnumber = 1


for column in data:
    if plotnumber<=10:
        ax=plt.subplot(4,2,plotnumber)
        sns.scatterplot(data[column],data['num_orders'],color = 'green')
        plt.xlabel(column,fontsize=7)
        
    plotnumber+=1
plt.show()

# %%
data.shape
# Out:
# (456548, 8)

# %%
plt.figure(figsize=(25,20),facecolor='lightblue')
plotnumber = 1


for column in data:
    if plotnumber<=10:
        ax=plt.subplot(4,2,plotnumber)
        sns.boxplot(data[column],color = 'green')
        plt.xlabel(column,fontsize=7)
        
    plotnumber+=1
plt.show()

# %%
data=data[data.num_orders<=525]
data=data[data.checkout_price<=750]

# %%
data
# Out:
#         week  center_id  meal_id  checkout_price  base_price  \
# 0          1         55     1885          136.83      152.29
# 1          1         55     1993          136.83      135.83
# 2          1         55     2539          134.86      135.86
# 3          1         55     2139          339.50      437.53
# 4          1         55     2631          243.50      242.50
# ...      ...        ...      ...             ...         ...
# 456542   145         61     2492          455.93      455.93
# 456543   145         61     1543          484.09      484.09
# 456544   145         61     2304          482.09      482.09
# 456545   145         61     2664          237.68      321.07
# 456547   145         61     2490          292.03      290.03
#
#         emailer_for_promotion  homepage_featured  num_orders
# 0                           0                  0         177
# 1                           0                  0         270
# ...

# %%
plt.figure(figsize=(25,20),facecolor='lightblue')
plotnumber = 1


for column in data:
    if plotnumber<=10:
        ax=plt.subplot(4,2,plotnumber)
        sns.boxplot(data[column],color = 'green')
        plt.xlabel(column,fontsize=7)
        
    plotnumber+=1
plt.show()

# %%
df_corr = data.corr().abs()

plt.figure(figsize =(12, 10))
sns.heatmap(df_corr, annot = True, annot_kws={'size' :10})
plt.show()

# %%
data.drop('num_orders',axis =1).corrwith(data.num_orders).plot(kind = 'bar', grid=True, figsize = (15,7))

# %%
data=data.drop(columns='base_price','week',axis=1)

# %%
data
# Out:
#         center_id  meal_id  checkout_price  emailer_for_promotion  \
# 0              55     1885          136.83                      0
# 1              55     1993          136.83                      0
# 2              55     2539          134.86                      0
# 3              55     2139          339.50                      0
# 4              55     2631          243.50                      0
# ...           ...      ...             ...                    ...
# 456542         61     2492          455.93                      0
# 456543         61     1543          484.09                      0
# 456544         61     2304          482.09                      0
# 456545         61     2664          237.68                      0
# 456547         61     2490          292.03                      0
#
#         homepage_featured  num_orders
# 0                       0         177
# 1                       0         270
# 2                       0         189
# ...

# %%
features = final_train.iloc[:,1:].values
label = final_train.iloc[:,:1].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import  LinearRegression

# %%
x_train,x_test,y_train,y_test = train_test_split(features,label,test_size=0.20,random_state=0)
model = LinearRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
from math import sqrt
print("R2 score  :",r2_score(y_test, y_pred))
print("MSE score  :",mean_squared_error(y_test, y_pred))
print("RMSE: ",sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score  : 0.1229221845056726
# MSE score  : 15017.4487161742
# RMSE:  122.54570052096565

# %%
x_train,x_test,y_train,y_test = train_test_split(features,label,test_size=0.20,random_state=0)
RFRmodel = RandomForestRegressor()
RFRmodel.fit(x_train,y_train)
y_pred = RFRmodel.predict(x_test)

# %%
print("R2 score  :",r2_score(y_test, y_pred))
print("MSE score  :",mean_squared_error(y_test, y_pred))
print("RMSE: ",sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score  : 0.7113904557331812
# MSE score  : 4941.612880246647
# RMSE:  70.29660646323298

# %%
x_train,x_test,y_train,y_test = train_test_split(features,label,test_size=0.20,random_state=0)
dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)

# %%
print("R2 score  :",r2_score(y_test, y_pred))
print("MSE score  :",mean_squared_error(y_test, y_pred))
print("RMSE: ",sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score  : 0.6363994341100062
# MSE score  : 6225.619614318264
# RMSE:  78.90259573878583

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb
from xgboost import XGBRegressor
model=XGBRegressor()

# %%
x_train,x_test,y_train,y_test = train_test_split(features,label,test_size=0.20,random_state=0)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
print("R2 score  :",r2_score(y_test, y_pred))
print("MSE score  :",mean_squared_error(y_test, y_pred))
print("RMSE: ",sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score  : 0.6902156179731054
# MSE score  : 5304.171406431721
# RMSE:  72.82974259484735

# %%
y_predict=RFRmodel.predict(x_test)

# %%
y_predict
# Out:
# array([233.0592381 , 438.63      ,  17.36067548, ...,  99.71250758,
#         40.4954294 , 125.88833333])

# %%
y_test
# Out:
# array([[161],
#        [325],
#        [ 14],
#        ...,
#        [ 82],
#        [ 69],
#        [ 53]], dtype=int64)

# %%
final_test=pd.read_csv('C:\\Users\\paas9002\\Downloads\\test.csv\\test.csv')

# %%
final_test=final_test.drop(columns=['id','base_price','week'],axis=1)

# %%
final_test
# Out:
#        center_id  meal_id  checkout_price  emailer_for_promotion  \
# 0             55     1885          158.11                      0
# 1             55     1993          160.11                      0
# 2             55     2539          157.14                      0
# 3             55     2631          162.02                      0
# 4             55     1248          163.93                      0
# ...          ...      ...             ...                    ...
# 32568         61     1543          482.09                      0
# 32569         61     2304          483.09                      0
# 32570         61     2664          322.07                      0
# 32571         61     2569          322.07                      0
# 32572         61     2490          276.45                      0
#
#        homepage_featured
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# ...

# %%
result_predict=RFRmodel.predict(final_test)

# %%
result_predict.tolist()
# Out:
# [104.70166666666665,
#  90.97,
#  175.43676190476197,
#  69.45916666666666,
#  54.17300000000002,
#  372.5471428571429,
#  320.94972222222225,
#  232.96109523809525,
#  137.33666666666667,
#  150.03033333333335,
#  98.32542934842934,
#  266.1526666666667,
#  383.54961149961144,
#  248.64582864357865,
#  153.57466666666664,
#  30.480708152958158,
#  268.4641179653679,
#  186.42638095238098,
#  127.72066666666666,
#  89.63333333333333,
#  135.04399999999998,
#  187.0934047619048,
#  48.744499999999995,
#  90.53166666666668,
#  119.73333333333333,
#  50.22383333333334,
#  18.035,
#  22.87133333333334,
#  27.122775419025412,
#  22.75975898581489,
#  22.632946941946944,
#  31.230988095238093,
#  343.4701666666666,
#  95.98836904761906,
#  212.88892513042512,
#  301.17,
#  335.86,
#  344.17941666666667,
#  99.14791919191917,
#  472.1084126984126,
#  338.3433333333333,
#  393.0421666666667,
#  125.80666666666667,
#  61.81331818181818,
#  151.06066666666663,
#  416.865,
# ...

# %%
result_predict=pd.DataFrame(result_predict)

# %%
result_predict.to_excel(r'C:\Users\paas9002\Desktop\export_dataframe.xlsx', index=False)
